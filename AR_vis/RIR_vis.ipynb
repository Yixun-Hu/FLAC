# %% [markdown]
# # Visualization of RIRs from AR dataset

# %%
import torchaudio
wav, sr = torchaudio.load("/home/yixunhu/codespace/FLAC/AcousticRooms/single_channel_ir_1/Apartments/Apartments_idx_0/S000_R002_hybrid_IR.wav")
print(f"wav.shape: {wav.shape}, sr: {sr}, wav.dtype: {wav.dtype}")
# Out:
# wav.shape: torch.Size([1, 22050]), sr: 22050, wav.dtype: torch.float32

# %%
import torch
x = torch.tensor([1., 2., 3.])
print(f"x shape: {x.shape}, x dtype: {x.dtype}")
x = x.unsqueeze(0)
print(f"x shape: {x.shape}, x: {x}")
xs = [torch.tensor([1., 2., 3.]),
      torch.tensor([4., 5., 6.]),
      torch.tensor([7., 8., 9.])]
print(f"xs shape: {xs.shape}")
# Out:
# x shape: torch.Size([3]), x dtype: torch.float32
# x shape: torch.Size([1, 3]), x: tensor([[1., 2., 3.]])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 9
#       5 print(f"x shape: {x.shape}, x: {x}")
#       6 xs = [torch.tensor([1., 2., 3.]),
#       7       torch.tensor([4., 5., 6.]),
#       8       torch.tensor([7., 8., 9.])]
# ----> 9 print(f"xs shape: {xs.shape}")
#
# AttributeError: 'list' object has no attribute 'shape'
